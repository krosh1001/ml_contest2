# %% [markdown]
# cd contest2
# source venv/bin/activate
# cd ../
# export LD_LIBRARY_PATH=$VIRTUAL_ENV/lib/python3.12/site-packages/nvidia/cudnn/lib:$VIRTUAL_ENV/lib/python3.12/site-packages/nvidia/cublas/lib:$VIRTUAL_ENV/lib/python3.12/site-packages/nvidia/cusolver/lib:$VIRTUAL_ENV/lib/python3.10/site-packages/nvidia/cusparse/lib
# python3 -c "import tensorflow as tf; print('Доступные GPU:', tf.config.list_physical_devices('GPU'))"
# jupyter notebook --no-browser

# %%
import os
import random
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications import EfficientNetV2B2

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

DATA_DIR = Path('.')
TRAIN_DIR = DATA_DIR / 'train'
TEST_DIR = DATA_DIR / 'test'
LABELS_PATH = DATA_DIR / 'labels.csv'
SAMPLE_SUBMISSION_PATH = DATA_DIR / 'sample_submission.csv'

IMG_SIZE = 256
BATCH_SIZE = 16
AUTOTUNE = tf.data.AUTOTUNE
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779889080.211190    6985 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("включено")
    except RuntimeError as e:
        print(e)
# Out:
# включено

# %%
labels = pd.read_csv(LABELS_PATH)
sample_submission = pd.read_csv(SAMPLE_SUBMISSION_PATH)

labels['filename'] = labels['id'].astype(str) + '.jpg'
labels['filepath'] = labels['filename'].apply(lambda name: str(TRAIN_DIR / name))

classes = sorted(labels['breed'].unique())
class_to_index = {breed: idx for idx, breed in enumerate(classes)}
labels['label'] = labels['breed'].map(class_to_index)

train_df, valid_df = train_test_split(
    labels,
    test_size=0.2,
    random_state=SEED,
    stratify=labels['breed'],
)

# %%
def decode_image(path, label=None):
    image = tf.io.read_file(path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    if label is None:
        return image
    return image, tf.one_hot(label, depth=len(classes))

def make_dataset(df, training=False):
    paths = df['filepath'].values
    labels_array = df['label'].values
    ds = tf.data.Dataset.from_tensor_slices((paths, labels_array))
    if training:
        ds = ds.shuffle(buffer_size=len(df), seed=SEED, reshuffle_each_iteration=True)
    ds = ds.map(decode_image, num_parallel_calls=AUTOTUNE)
    ds = ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)
    return ds

train_ds = make_dataset(train_df, training=True)
valid_ds = make_dataset(valid_df, training=False)
# Out:
# I0000 00:00:1779889106.683599    6985 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3582 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
augmentation = keras.Sequential(
    [
        layers.RandomFlip('horizontal', seed=SEED),
        layers.RandomRotation(0.15, seed=SEED),
        layers.RandomZoom(0.15, seed=SEED),
        layers.RandomTranslation(0.1, 0.1, seed=SEED),
        layers.RandomBrightness(factor=0.2, seed=SEED),
        layers.RandomContrast(factor=0.2, seed=SEED),
    ],
    name='augmentation',
)

# %%
def build_model():
    inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = augmentation(inputs)

    base_model = EfficientNetV2B2(
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
        include_top=False,
        weights='imagenet',
    )
    base_model.trainable = False 

    x = base_model(x, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.4)(x) 
    
    outputs = layers.Dense(
        len(classes), 
        activation='softmax',
        kernel_regularizer=keras.regularizers.l2(1e-4)
    )(x)

    model = keras.Model(inputs, outputs)
    return model, base_model

model, base_model = build_model()

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss = keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy', keras.metrics.TopKCategoricalAccuracy(k=5, name='top_5_accuracy')],
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b2_notop.h5
# 35839040/35839040 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
callbacks_phase1 = [
    keras.callbacks.ModelCheckpoint(
        'efficientnetv2b2_dog_breeds_phase1.keras',
        monitor='val_loss',
        save_best_only=True,
    ),
    keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=3,
        restore_best_weights=True,
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.2,
        patience=2,
        min_lr=1e-6,
    ),
]

initial_epochs = 6
history_frozen = model.fit(
    train_ds,
    validation_data=valid_ds,
    epochs=initial_epochs,
    callbacks=callbacks_phase1,
)
# Out:
# Epoch 1/6
# I0000 00:00:1779889131.592777    7060 cuda_dnn.cc:461] Loaded cuDNN version 92200
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 69s 102ms/step - accuracy: 0.5852 - loss: 2.4732 - top_5_accuracy: 0.8279 - val_accuracy: 0.8958 - val_loss: 1.2462 - val_top_5_accuracy: 0.9946 - learning_rate: 0.0010
# Epoch 2/6
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 45s 87ms/step - accuracy: 0.7532 - loss: 1.6838 - top_5_accuracy: 0.9463 - val_accuracy: 0.9051 - val_loss: 1.2011 - val_top_5_accuracy: 0.9927 - learning_rate: 0.0010
# Epoch 3/6
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 45s 88ms/step - accuracy: 0.7801 - loss: 1.6081 - top_5_accuracy: 0.9571 - val_accuracy: 0.9115 - val_loss: 1.1959 - val_top_5_accuracy: 0.9941 - learning_rate: 0.0010
# Epoch 4/6
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - accuracy: 0.7848 - loss: 1.5908 - top_5_accuracy: 0.9561 - val_accuracy: 0.9105 - val_loss: 1.1972 - val_top_5_accuracy: 0.9946 - learning_rate: 0.0010
# Epoch 5/6
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 47s 91ms/step - accuracy: 0.8029 - loss: 1.5497 - top_5_accuracy: 0.9615 - val_accuracy: 0.9081 - val_loss: 1.2013 - val_top_5_accuracy: 0.9932 - learning_rate: 0.0010
# Epoch 6/6
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - accuracy: 0.8289 - loss: 1.4827 - top_5_accuracy: 0.9704 - val_accuracy: 0.9144 - val_loss: 1.1870 - val_top_5_accuracy: 0.9941 - learning_rate: 2.0000e-04

# %%
base_model.trainable = True

fine_tune_at = len(base_model.layers) // 2
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False
for layer in base_model.layers[fine_tune_at:]:
    layer.trainable = True

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-5), 
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy', keras.metrics.TopKCategoricalAccuracy(k=5, name='top_5_accuracy')],
)

callbacks_phase2 = [
    keras.callbacks.ModelCheckpoint(
        'efficientnetv2b2_dog_breeds_fine.keras',
        monitor='val_loss',
        save_best_only=True,
    ),
    keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=5,            
        restore_best_weights=True,
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=2,
        min_lr=1e-7,
    ),
]

fine_tune_epochs = 10
total_epochs = initial_epochs + fine_tune_epochs

history_fine = model.fit(
    train_ds,
    validation_data=valid_ds,
    epochs=total_epochs,
    initial_epoch=history_frozen.epoch[-1] + 1, 
    callbacks=callbacks_phase2,
)
# Out:
# Epoch 7/16
# E0000 00:00:1779889440.810388    6985 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/functional_1_1/efficientnetv2-b2_1/block1b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 145s 219ms/step - accuracy: 0.6436 - loss: 2.3191 - top_5_accuracy: 0.8852 - val_accuracy: 0.8782 - val_loss: 1.3798 - val_top_5_accuracy: 0.9922 - learning_rate: 1.0000e-05
# Epoch 8/16
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 108s 211ms/step - accuracy: 0.6967 - loss: 1.9996 - top_5_accuracy: 0.9231 - val_accuracy: 0.8831 - val_loss: 1.3071 - val_top_5_accuracy: 0.9927 - learning_rate: 1.0000e-05
# Epoch 9/16
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 100s 196ms/step - accuracy: 0.7355 - loss: 1.8407 - top_5_accuracy: 0.9425 - val_accuracy: 0.8875 - val_loss: 1.2780 - val_top_5_accuracy: 0.9941 - learning_rate: 1.0000e-05
# Epoch 10/16
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 103s 201ms/step - accuracy: 0.7435 - loss: 1.7807 - top_5_accuracy: 0.9483 - val_accuracy: 0.8870 - val_loss: 1.2671 - val_top_5_accuracy: 0.9936 - learning_rate: 1.0000e-05
# Epoch 11/16
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 102s 198ms/step - accuracy: 0.7650 - loss: 1.7133 - top_5_accuracy: 0.9574 - val_accuracy: 0.8924 - val_loss: 1.2624 - val_top_5_accuracy: 0.9917 - learning_rate: 1.0000e-05
# Epoch 12/16
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 100s 196ms/step - accuracy: 0.7850 - loss: 1.6637 - top_5_accuracy: 0.9623 - val_accuracy: 0.8954 - val_loss: 1.2385 - val_top_5_accuracy: 0.9936 - learning_rate: 1.0000e-05
# Epoch 13/16
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 95s 186ms/step - accuracy: 0.7794 - loss: 1.6597 - top_5_accuracy: 0.9622 - val_accuracy: 0.8895 - val_loss: 1.2564 - val_top_5_accuracy: 0.9941 - learning_rate: 1.0000e-05
# Epoch 14/16
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 99s 194ms/step - accuracy: 0.7920 - loss: 1.6133 - top_5_accuracy: 0.9689 - val_accuracy: 0.8929 - val_loss: 1.2520 - val_top_5_accuracy: 0.9956 - learning_rate: 1.0000e-05
# Epoch 15/16
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 98s 192ms/step - accuracy: 0.8003 - loss: 1.5888 - top_5_accuracy: 0.9684 - val_accuracy: 0.8919 - val_loss: 1.2428 - val_top_5_accuracy: 0.9927 - learning_rate: 5.0000e-06
# Epoch 16/16
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 101s 197ms/step - accuracy: 0.8031 - loss: 1.5887 - top_5_accuracy: 0.9729 - val_accuracy: 0.8963 - val_loss: 1.2370 - val_top_5_accuracy: 0.9932 - learning_rate: 5.0000e-06

# %%
test_paths = [str(TEST_DIR / f'{image_id}.jpg') for image_id in sample_submission['id']]
test_ds = tf.data.Dataset.from_tensor_slices(test_paths)
test_ds = test_ds.map(lambda path: decode_image(path), num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)

predictions = model.predict(test_ds, verbose=0)

submission = pd.DataFrame(predictions, columns=classes)
submission.insert(0, 'id', sample_submission['id'].values)
submission = submission[sample_submission.columns]
submission.to_csv('submission4.csv', index=False)
